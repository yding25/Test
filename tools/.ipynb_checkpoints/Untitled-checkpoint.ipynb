# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')

# method 1: Our
risk = [0, 200]
cost = [0, 200]
pref = [0, 200]
ax.plot3D(risk, cost, pref, 'black')
ax.scatter3D(risk[1], cost[1], pref[1]);

# method 2: Our
risk = [0, 210]
cost = [0, 250]
pref = [0, 200]
ax.plot3D(risk, cost, pref, 'black')
ax.scatter3D(risk[1], cost[1], pref[1]);

# method 3: Our
risk = [0, 220]
cost = [0, 200]
pref = [0, 240]
ax.plot3D(risk, cost, pref, 'black')
ax.scatter3D(risk[1], cost[1], pref[1]);

# method 4: Our
risk = [0, 230]
cost = [0, 220]
pref = [0, 200]
ax.plot3D(risk, cost, pref, 'black')
ax.scatter3D(risk[1], cost[1], pref[1]);

plt.xlim([200, 250])
plt.ylim([200, 250])
ax.set_zlim([200, 250])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_25512/1849723889.py in <module>
#      34 plt.xlim([200, 250])
#      35 plt.ylim([200, 250])
# ---> 36 plt.set_zlim([200, 250])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_zlim'
